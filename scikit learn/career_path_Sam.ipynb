# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
df = pd.read_csv('career_path_original.csv')

# %%
df.head(50)
# Out:
#            skills_required   Skill_level                    interests  \
# 0                   Python      beginner                     Analysis
# 1                   Python      beginner                     Analysis
# 2                   Python      beginner                     Analysis
# 3         Machine Learning  intermediate      Artificial Intelligence
# 4         Machine Learning  intermediate      Artificial Intelligence
# 5         Machine Learning  intermediate      Artificial Intelligence
# 6               Statistics      advanced          Predictive Modeling
# 7               Statistics      advanced          Predictive Modeling
# 8               Statistics      advanced          Predictive Modeling
# 9                     Java      beginner         Software Development
# 10                    Java      beginner         Software Development
# 11                    Java      beginner         Software Development
# 12                     C++  intermediate                       Coding
# 13                     C++  intermediate                       Coding
# 14                     C++  intermediate                       Coding
# 15    Software Development      advanced              Problem-Solving
# 16    Software Development      advanced              Problem-Solving
# 17    Software Development      advanced              Problem-Solving
# 18      Product Management      beginner          Product Development
# 19      Product Management      beginner          Product Development
# 20      Product Management      beginner          Product Development
# 21         Market Research  intermediate                User Feedback
# 22         Market Research  intermediate                User Feedback
# 23         Market Research  intermediate                User Feedback
# 24  User Experience Design      beginner         User-Centered Design
# 25  User Experience Design      beginner         User-Centered Design
# 26  User Experience Design      beginner         User-Centered Design
# 27             Wireframing  intermediate            Usability Testing
# 28             Wireframing  intermediate            Usability Testing
# 29             Wireframing  intermediate            Usability Testing
# 30                     SQL      beginner               Interpretation
# 31                     SQL      beginner               Interpretation
# 32                     SQL      beginner               Interpretation
# 33                Analysis  intermediate              Trends Analysis
# 34                Analysis  intermediate              Trends Analysis
# 35                Analysis  intermediate              Trends Analysis
# 36           Visualization      advanced                Visualization
# 37           Visualization      advanced                Visualization
# 38           Visualization      advanced                Visualization
# 39                  Python      beginner  Machine Learning Algorithms
# 40                  Python      beginner  Machine Learning Algorithms
# 41                  Python      beginner  Machine Learning Algorithms
# 42              TensorFlow  intermediate                Deep Learning
# 43              TensorFlow  intermediate                Deep Learning
# 44              TensorFlow  intermediate                Deep Learning
# 45         Neural Networks      advanced           Model Optimization
# 46         Neural Networks      advanced           Model Optimization
# 47         Neural Networks      advanced           Model Optimization
# 48                    HTML      beginner                   Web Design
# 49                    HTML      beginner                   Web Design
#
#     interest_Levels                     Career  assessment_score
# 0               0.5             Data Scientist               0.5
# 1               0.7             Data Scientist               0.6
# 2               0.9             Data Scientist               0.7
# 3               0.5             Data Scientist               0.8
# 4               0.7             Data Scientist               0.9
# 5               0.9             Data Scientist               0.5
# 6               0.5             Data Scientist               0.6
# 7               0.7             Data Scientist               0.7
# 8               0.9             Data Scientist               0.8
# 9               0.5          Software Engineer               0.5
# 10              0.7          Software Engineer               0.6
# 11              0.9          Software Engineer               0.7
# 12              0.5          Software Engineer               0.8
# 13              0.7          Software Engineer               0.9
# 14              0.9          Software Engineer               0.5
# 15              0.5          Software Engineer               0.6
# 16              0.7          Software Engineer               0.7
# 17              0.9          Software Engineer               0.8
# 18              0.5            Product Manager               0.5
# 19              0.7            Product Manager               0.6
# 20              0.9            Product Manager               0.7
# 21              0.5            Product Manager               0.8
# 22              0.7            Product Manager               0.9
# 23              0.9            Product Manager               0.5
# 24              0.5                UX Designer               0.5
# 25              0.7                UX Designer               0.6
# 26              0.9                UX Designer               0.7
# 27              0.5                UX Designer               0.8
# 28              0.7                UX Designer               0.9
# 29              0.9                UX Designer               0.5
# 30              0.5               Data Analyst               0.5
# 31              0.7               Data Analyst               0.6
# 32              0.9               Data Analyst               0.7
# 33              0.5               Data Analyst               0.8
# 34              0.7               Data Analyst               0.9
# 35              0.9               Data Analyst               0.5
# 36              0.5               Data Analyst               0.6
# 37              0.7               Data Analyst               0.7
# 38              0.9               Data Analyst               0.8
# 39              0.5  Machine Learning Engineer               0.5
# 40              0.7  Machine Learning Engineer               0.6
# 41              0.9  Machine Learning Engineer               0.7
# 42              0.5  Machine Learning Engineer               0.8
# 43              0.7  Machine Learning Engineer               0.9
# 44              0.9  Machine Learning Engineer               0.5
# 45              0.5  Machine Learning Engineer               0.6
# 46              0.7  Machine Learning Engineer               0.7
# 47              0.9  Machine Learning Engineer               0.8
# 48              0.5         Frontend Developer               0.5
# 49              0.7         Frontend Developer               0.6

# %%
df.describe(include = "all")
# Out:
#        skills_required Skill_level interests  interest_Levels         Career  \
# count             3090        3090      3090      3090.000000           3090
# unique             690           3       810              NaN            337
# top           Analysis    beginner  Research              NaN  Archaeologist
# freq                78        1089        21              NaN             27
# mean               NaN         NaN       NaN         0.700000            NaN
# std                NaN         NaN       NaN         0.163326            NaN
# min                NaN         NaN       NaN         0.500000            NaN
# 25%                NaN         NaN       NaN         0.500000            NaN
# 50%                NaN         NaN       NaN         0.700000            NaN
# 75%                NaN         NaN       NaN         0.900000            NaN
# max                NaN         NaN       NaN         0.900000            NaN
#
#         assessment_score
# count        3090.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean            0.676149
# std             0.132672
# min             0.500000
# 25%             0.600000
# 50%             0.700000
# 75%             0.800000
# max             0.900000

# %%
# Finding the unique values for the various columns

## Define a function to strip whitespaces from a single element
def strip_whitespaces(element):
    return str(element).strip()

df['interests'] = df['interests'].apply(strip_whitespaces)

df['interests'].unique()
# Out:
# array(['Analysis', 'Artificial Intelligence', 'Predictive Modeling',
#        'Software Development', 'Coding', 'Problem-Solving',
#        'Product Development', 'User Feedback', 'User-Centered Design',
#        'Usability Testing', 'Interpretation', 'Trends Analysis',
#        'Visualization', 'Machine Learning Algorithms', 'Deep Learning',
#        'Model Optimization', 'Web Design', 'Frontend Frameworks',
#        'User Interface', 'Server-Side Logic', 'base Management',
#        'API Development', 'End-to-End Development',
#        'Cross-Functional Skills', 'Code Integration', 'Visual Design',
#        'Web Layout', 'User Experience', 'Process Improvement',
#        'Business Efficiency', 'Security', 'base Optimization',
#        'Network Infrastructure', 'Connectivity Solutions',
#        'Continuous Integration', 'Deployment Automation',
#        'Cloud Architecture', 'Scalable Solutions', 'Sales Strategies',
#        'Customer Engagement', 'Market Analysis', 'Marketing Campaigns',
#        'Brand Promotion', 'Financial Modeling', 'Investment Analysis',
#        'Employee Development', 'HR Policies', 'Project Planning',
#        'Stakeholder Management', 'Creative Writing', 'Content Creation',
#        'Visual Creativity', 'Graphic Artistry', 'Threat Detection',
#        'Security Protocols', 'QA Testing', 'Bug Tracking', 'AI Research',
#        'Internet of Things', 'Sensor Networks', 'Online Marketing',
#        'Web Analytics', 'Customer Service', 'Game Design',
#        'Gameplay Mechanics', 'Mobile Apps', 'App Design',
#        'Quality Assurance', 'Business Processes', 'System Efficiency',
#        'Hardware Maintenance', 'Documentation', 'Inventory Control',
#        'Logistics Planning', 'Process Optimization', 'Design Innovation',
#        'Product Aesthetics', 'Social Media Campaigns',
#        'Content Marketing', 'Accuracy', 'Management', 'Business Strategy',
#        'Client Consulting', 'Technical Repairs', 'Equipment Maintenance',
#        'Healthcare', 'Patient Well-being', 'Artistic Creation',
#        'Financial Records', 'Bookkeeping', 'Financial Transactions',
#        'Ledger Maintenance', 'Financial Oversight',
#        'Accounting Leadership', 'Medical Research', 'Patient Care',
#        'Disease Diagnosis', 'Medication Management', 'Patient Counseling',
#        'Physical Rehabilitation', 'Injury Recovery', 'Radiology Imaging',
#        'Disease Detection', 'Surgical Techniques',
#        'Life-Saving Procedures', 'Surgical Innovation', 'Mental Health',
#        'Mechanical Systems', 'Innovation', 'Infrastructure Development',
#        'Building Design', 'Urban Planning', 'Electrical Systems',
#        'Electronics', 'Energy Solutions', 'Aerospace Innovation',
#        'Space Exploration', 'Aircraft Design', 'Software Coding',
#        'Application Development', 'Software Innovation',
#        'Medical Technology', 'Biomedical Innovation',
#        'Healthcare Solutions', 'Frontend Development',
#        'User Experience Design', 'Web Technologies', 'Insights',
#        'Network Security', 'IT Infrastructure', 'Network Optimization',
#        'Cybersecurity', 'Threat Mitigation', 'Information Protection',
#        'base Administration', 'Integrity', 'Test Plans',
#        'Software Reliability', 'Education', 'Student Development',
#        'Teaching Techniques', 'Student Well-being', 'Counseling',
#        'Career Guidance', 'Literature', 'Information Management',
#        'Reading Promotion', 'Student Evaluation',
#        'Special Needs Education', 'Learning Assessment',
#        'Student Mental Health', 'Psychological Evaluation', 'Tutoring',
#        'Academic Improvement', 'Student Progress', 'Legal Practice',
#        'Justice', 'Legal Rights', 'Criminal Defense', 'Legal Advocacy',
#        'Fair Trials', 'Corporate Law', 'Business Ethics',
#        'Legal Compliance', 'Family Law', 'Mediation', 'Family Well-being',
#        'Environmental Protection', 'Sustainability', 'Immigration Law',
#        'Cross-Cultural Relations', 'Immigrant Rights',
#        'Financial Analysis', 'Accounting Principles', 'Financial Markets',
#        'Marketing Innovation', 'Brand Development', 'Consumer Behavior',
#        'Sales Growth', 'Team Motivation', 'Revenue Generation',
#        'Portfolio Optimization', 'Investment Strategies',
#        'Human Resources', 'Workplace Culture', 'Visual Arts',
#        'Creative Expression', 'Artistic Innovation', 'Theater', 'Film',
#        'Storytelling', 'Music Creation', 'Performance',
#        'Musical Innovation', 'Branding', 'Creative Problem-Solving',
#        'Film Production', 'Cinematic Vision', 'Photography',
#        'Visual Storytelling', 'Image Capture',
#        'Environmental Conservation', 'Ecosystems', 'Research',
#        'Marine Life', 'Ocean Conservation', 'Geological Processes',
#        'Earth History', 'Field Research', 'Weather Patterns',
#        'Climate Science', 'Forecasting', 'Animal Biology',
#        'Wildlife Conservation', 'Outdoor Activities', 'Nutrition',
#        'Dietary Health', 'Wellness Promotion', 'Physical Fitness',
#        'Exercise Science', 'Personal Training', 'Rehabilitation',
#        'Adaptive Techniques', 'Spinal Health', 'Holistic Medicine',
#        'Pain Relief', 'Speech and Language Development',
#        'Communication Improvement', 'Patient Support',
#        'Emotional Well-being', 'Flying', 'Aviation', 'Aeronautics',
#        'Aerospace Technology', 'Aviation Safety', 'Aircraft Guidance',
#        'Communication', 'Travel', 'Passenger Care', 'In-Flight Service',
#        'Aircraft Maintenance', 'Engineering', 'Mechanical Skills',
#        'Weather Analysis', 'Climate Patterns', 'Inclusive Education',
#        'Student Support', 'Teaching Strategies', 'Learning Disabilities',
#        'Student Success', 'Educational Support', 'Autism Support',
#        'Behavioral Analysis', 'Autism Research', 'Execution',
#        'Goal Achievement', 'Team Leadership', 'Supply Chain Optimization',
#        'Inventory Management', 'Logistics', 'Business Insights',
#        'Community Protection', 'Crime Prevention', 'Law Enforcement',
#        'Fire Suppression', 'Rescue Operations', 'Public Safety',
#        'Medical Response', 'Life-saving Interventions', 'Emergency Care',
#        'Criminal Justice', 'Forensics', 'Solving Crimes',
#        'Scientific Analysis', 'Crime Scene Examination',
#        'Evidence Processing', 'Crisis Management', 'Hospitality',
#        'Guest Satisfaction', 'Hotel Operations', 'Culinary Excellence',
#        'Guest Experience', 'Restaurant Operations', 'Travel Destinations',
#        'Vacation Planning', 'Customer Satisfaction', 'Mixology',
#        'Beverage Preparation', 'Customer Interaction',
#        'Culinary Creativity', 'Food Preparation', 'Culinary Arts',
#        'Cultural Exploration', 'Educational Excellence',
#        'School Leadership', 'School Operations',
#        'Administrative Efficiency', 'Educational Policy',
#        'District Improvement', 'Educational Leadership',
#        'Education Innovation', 'Educational Solutions',
#        'Curriculum Design', 'Educational Content Creation',
#        'Curriculum Innovation', 'Educational Materials',
#        'Education Research', 'Physical Health', 'Occupational Health',
#        'Patient Independence', 'Therapeutic Activities',
#        'Medical Imaging', 'Diagnostic Procedures', 'Patient Safety',
#        'Speech Therapy', 'Patient Progress', 'Respiratory Health',
#        'Breathing Disorders', 'Surgical Procedures',
#        'Operating Room Support', 'Sterile Techniques', 'Stock Trading',
#        'Financial Strategy', 'Wealth Management',
#        'Client Financial Goals', 'Corporate Finance', 'Capital Markets',
#        'Deal Structuring', 'Tax Strategies', 'Compliance',
#        'Tax Efficiency', 'Asset Management', 'Credit Risk',
#        'Lending Decisions', 'Sculpture', 'Artistic Expression',
#        'Three-Dimensional Art', 'Artistic Creativity', 'Graphic Design',
#        'Art Appreciation', 'Curating Exhibitions', 'Game Development',
#        'Interactive Media', 'Clay Sculpting', 'Pottery',
#        'Ceramic Artistry', 'Reputation Management',
#        'Communication Strategies', 'Public Image', 'Social Media Trends',
#        'Content Strategy', 'Community Building', 'Persuasive Writing',
#        'Advertising Campaigns', 'Broadcast Journalism', 'News Reporting',
#        'Live News Presentation', 'Radio Production',
#        'Music or Talk Shows', 'Audio Entertainment', 'Social Services',
#        'Helping Others', 'Advocacy', 'Nonprofit Missions',
#        'Community Impact', 'Program Development', 'Social Justice',
#        'Grassroots Movements', 'Community Empowerment',
#        'Substance Abuse Recovery', 'Helping Individuals',
#        'Youth Development', 'Empowering Young People', 'Mentorship',
#        'Child Advocacy', 'Child Welfare Services', 'Family Support',
#        'Ecosystem Conservation', 'Wildlife Preservation', 'Biodiversity',
#        'Wildlife Research', 'Animal Behavior', 'Environmental Awareness',
#        'Forest Conservation', 'Ecosystem Protection',
#        'Sustainable Practices', 'Green Technologies',
#        'Corporate Sustainability', 'Environmental Solutions',
#        'Impact Assessment', 'Cybersecurity Challenges',
#        'Security Testing', 'Vulnerability Assessment', 'Protection',
#        'Cybersecurity Strategies', 'Encryption', 'Codebreaking',
#        'Cybersecurity Solutions', 'Security Audits', 'Client Protection',
#        'Digital Crime Investigation', 'Recovery', 'Cybersecurity Threats',
#        'Malware Research', 'Cyber Defense', 'Long-Distance Travel',
#        'Cargo Transport', 'On-the-Road Experience', 'Air Travel',
#        'Air Traffic Coordination', 'Airport Operations',
#        'Freight Management', 'Supply Chain Efficiency', 'Transportation',
#        'Maritime Adventures', 'Ocean Travel', 'Nautical Operations',
#        'Cosmic Phenomena', 'Theoretical Physics', 'Subatomic Particles',
#        'High-Energy Physics', 'Collider Experiments', 'Health Research',
#        'Epidemiology', 'Cultural Diversity', 'Anthropology',
#        'Social Observation', 'Historical Discoveries',
#        'Cultural Heritage', 'Archaeological Sites', 'Medical Science',
#        'Health Discoveries', 'Disease Research', 'Startups',
#        'Business Growth', 'Local Business', 'Customer Relationships',
#        'Ownership', 'Business Ownership', 'Franchise Models',
#        'Brand Loyalty', 'Startup Investments', 'High-Growth Ventures',
#        'Business Improvement', 'Client Solutions', 'Industry Expertise',
#        'Entrepreneurship', 'Early-Stage Ventures',
#        'Cybersecurity Governance', 'Risk Mitigation',
#        'Security Leadership', 'Security Monitoring',
#        'Incident Investigation', 'Network Protection',
#        'Firewall Management', 'Threat Prevention',
#        'Cybersecurity Testing', 'Vulnerability Discovery',
#        'Security Improvement', 'Security Management',
#        'User Access Control', 'Policy Enforcement', 'Cancer Treatment',
#        'Patient Well-Being', 'Diagnostic Testing', 'Pharmacy Operations',
#        'Eye Health', 'Vision Correction', 'Diagnostic Sonography',
#        'Patient Comfort', 'Healthcare Administration',
#        'Billing Processes', 'Revenue Cycle', 'Brand Storytelling',
#        'Audience Engagement', 'Visual Communication', 'Creative Concepts',
#        'Brand Identity', 'Organic Search', 'Website Rankings',
#        'Algorithm Changes', 'Competitive Analysis', 'Industry Trends',
#        'Ethnography', 'Human Societies', 'Social Dynamics',
#        'Group Behavior', 'Social Trends', 'Historical Preservation',
#        'Artifact Discovery', 'Cultural History', 'Historical Narratives',
#        'Document Analysis', 'Time Periods', 'Political Systems',
#        'Policy Development', 'Governance', 'Geographic Patterns',
#        'Environmental Studies', 'Cartography', 'Diagnostic Imaging',
#        'Medical Visualization', 'Scientific Art', 'Healthcare Education',
#        'Healthcare Quality', 'Medical Documentation',
#        'Healthcare Support', 'Legal Processes', 'Case Support',
#        'Legal Procedures', 'Client Services', 'Case Coordination',
#        'Verbatim Recording', 'Legal Proceedings',
#        'Administrative Support', 'Legal Documentation',
#        'Law Office Operations', 'Dispute Resolution',
#        'Neutral Facilitation', 'Conflict Management', 'Impartiality',
#        'Automotive Technology', 'Problem Solving', 'Mechanical Repair',
#        'Vehicle Design', 'Engineering Innovation',
#        'Transportation Management', 'Route Planning', 'Coordination',
#        'Aviation Technology', 'Safety', 'Vehicle Aesthetics',
#        'Automotive Styling', 'Vehicle Restoration',
#        'Automotive Craftsmanship', 'Bodywork', 'Athletic Training',
#        'Sports Strategy', 'Sports Program Management', 'Leadership',
#        'School Athletics', 'Athlete Management', 'Contract Negotiation',
#        'Sports Business', 'Human Performance', 'Fitness Research',
#        'Athlete Health', 'Sports Nutrition', 'Healthy Eating',
#        'Dietary Science', 'Athlete Psychology', 'Mental Toughness',
#        'Performance Enhancement', 'Dessert Creation',
#        'Artistic Presentation', 'Wine Appreciation', 'Grape Varieties',
#        'Culinary Pairing', 'Food Service', 'Event Catering',
#        'Food Technology', 'Culinary Innovation', 'Nutrition Science',
#        'Craft Brewing', 'Beer Styles', 'Flavor Profiles',
#        'Food Photography', 'Culinary Design', 'Visual Aesthetics',
#        'HR Administration', 'Employee Engagement', 'Labor Regulations',
#        'Workplace Behavior', 'Employee Well-Being',
#        'Organizational Development', 'Salary Planning',
#        'Benefits Evaluation', 'Pay Equity', 'HR Strategy Alignment',
#        'Organizational Success', 'Talent Development',
#        'Workplace Harmony', 'Employee Advocacy', 'Diversity Initiatives',
#        'Inclusion Strategies', 'Equity Advocacy', 'Fashion Trends',
#        'Personal Styling', 'Fabric Artistry', 'Pattern Design',
#        'Textile Innovation', 'Clothing Design', 'Garment Fitting',
#        'Pattern Creation', 'Fashion Retail', 'Market Trends',
#        'Fashion Purchasing', 'Market Research', 'Trend Forecasting',
#        'Costume Creation', 'Quality Standards', 'Product Testing',
#        'Regulatory Compliance', 'Product Approvals',
#        'Government Regulations', 'Ethical Conduct', 'Policy Adherence',
#        'Software Quality', 'Testing Strategies', 'Defect Prevention',
#        'Workplace Safety', 'Risk Assessment', 'Safety Compliance',
#        'Audit Processes', 'Quality Assessment', 'Compliance Evaluation',
#        'Learning Design', 'Online Education', 'Educational Engagement',
#        'Educational Technology', 'Building Client Relationships',
#        'Learning Technology', 'User Support', 'Game-Based Learning',
#        'Technology Integration', 'Pedagogy', 'Educational Innovation',
#        'Crop and Soil Science', 'Agricultural Research', 'Crop Health',
#        'Pest Control', 'Farm Efficiency',
#        'Agricultural Business Strategies', 'Financial Management',
#        'Crop Production', 'Sustainable Agriculture',
#        'Environmental Stewardship', 'Livestock Rearing', 'Animal Welfare',
#        'Farm Operations', 'Agricultural Markets', 'Economic Trends',
#        'Policy Analysis', 'Forest Management', 'Environmental',
#        'Wildlife Protection', 'Biodiversity Conservation',
#        'Ecosystem Management', 'Ecosystem Dynamics', 'Forest Research',
#        'Environmental Impact', 'Tree Health', 'Urban Forestry',
#        'Arboriculture', 'Soil Health', 'Agricultural Sustainability',
#        'Defense Strategy', 'National Service', 'National Security',
#        'Information Analysis', 'Threat Assessment', 'Military Tactics',
#        'Geopolitical Analysis', 'Law and Order', 'Discipline',
#        'Base Security', 'Moral Support', 'Islamic Faith',
#        'Christian Faith', 'Interfaith Service', 'Scholarly Work',
#        'Human-Computer Interaction', 'Usability', 'Product Innovation',
#        'Form and Function', 'Consumer Needs', 'Animation Techniques',
#        'Event Design', 'Client Relations', 'Professional Networking',
#        'Conference Planning', 'Travel and Tourism',
#        'Destination Marketing', '3D Design', 'Urban Development',
#        'Community Improvement', 'Sustainable Cities', 'Outdoor Spaces',
#        'Aesthetics', 'Interior Aesthetics', 'Functional Design',
#        'Client Collaboration', 'Traveling', 'Adventure',
#        'Itinerary Creation', 'Collaboration', 'Theater Arts',
#        'Creative Collaboration', 'Dance', 'Rhythm', 'Audio Production',
#        'Recording Technology', 'Music Engineering',
#        'Theatrical Production', 'Backstage Management', 'Acting Talent',
#        'Talent Discovery', 'Property Sales', 'Real Estate Market Trends',
#        'Property Management', 'Investment Properties',
#        'Real Estate Operations', 'Property Leasing', 'Tenant Relations',
#        'Marketing', 'Property Condition Assessment', 'Quality Control',
#        'Science', 'Scientific Discovery', 'Spacecraft Development',
#        'Technology Innovation', 'Satellite Technology', 'Transmission',
#        'Space Communication', 'Multilingualism', 'Cultural Exchange',
#        'Multilingual Communication', 'Language Mediation',
#        'Cross-Cultural Understanding', 'Deaf Community',
#        'Communication Access', 'Legal Interpreting', 'Justice System',
#        'Cross-Cultural Storytelling', 'Language and Artistry',
#        'Global Commerce', 'Export-Import', 'Cross-Border Business',
#        'Export Operations', 'Market Expansion', 'Global Trade',
#        'Customs Compliance', 'Trade Compliance', 'Regulatory Knowledge',
#        'International Business Expansion', 'Client Advising',
#        'Trade  Analysis', 'International Economics', 'Crafting',
#        'Precision Work', 'Manufacturing', 'Interpersonal Interaction',
#        'Administrative Work', 'Customer Care', 'Optimization',
#        'Technical Work', 'Construction', 'Design', 'Creativity',
#        'Building Planning', 'Wellness', 'Alternative Medicine',
#        'Oral Health', 'Patient Interaction', 'Medical Support',
#        'Disease Patterns', 'Public Health', 'Animal Health',
#        'Veterinary Science', 'Compassion', 'Medicine', 'Laboratory Work',
#        'Medical Testing', 'Precision', 'Cellular Analysis',
#        'Health and Wellness', 'Finance', 'Investments',
#        'Helping Others with Finances', 'Public Service', 'Government',
#        'Policy Making', 'Mechanical Processes', 'Building',
#        'Skilled Trades', 'Mathematics', 'Logic', 'Abstract Thinking',
#        "Women's Health", 'Childbirth', 'Patient Advocacy', 'Energy',
#        'Geology', 'Nursing', 'Earth Sciences', 'Geophysics',
#        'Natural Disasters', 'Data', 'Beauty', 'Skincare', 'History',
#        'Fieldwork', 'Accounting', 'Molecular Biology', 'Biology',
#        'Ecology', 'News', 'Current Events', 'Reporting'], dtype=object)

# %% [markdown]
# So we have 337 different classes for career

# %%
## Since there are no missing values, we move straight to encoding the categorical columns
### Now we encode the categorical values since the machine cannot understand it
# Label encoding
le_skills_required = LabelEncoder()
le_skill_level = LabelEncoder()
le_int = LabelEncoder()
le_career = LabelEncoder()

df["interests"] = le_int.fit_transform(df["interests"])
df["skills_required"] = le_skills_required.fit_transform(df["skills_required"])
df["Skill_level"] = le_skill_level.fit_transform(df["Skill_level"])
df["Career"] = le_career.fit_transform(df["Career"])

# %%
df.head()
# Out:
#    skills_required  Skill_level  interests  interest_Levels  Career  \
# 0              503            1         33              0.5      84
# 1              503            1         33              0.7      84
# 2              503            1         33              0.9      84
# 3              364            2         46              0.5      84
# 4              364            2         46              0.7      84
#
#    assessment_score
# 0               0.5
# 1               0.6
# 2               0.7
# 3               0.8
# 4               0.9

# %% [markdown]
# There is no need to standardize the numeric data since they are all in between 0 and 1

# %%
y = df['Career']
X= df.drop("Career",axis =1)

# %%
y
# Out:
# 0       84
# 1       84
# 2       84
# 3       84
# 4       84
#         ..
# 3085    46
# 3086    46
# 3087    46
# 3088    46
# 3089    46
# Name: Career, Length: 3090, dtype: int32

# %%
X
# Out:
#       skills_required  Skill_level  interests  interest_Levels  \
# 0                 503            1         33              0.5
# 1                 503            1         33              0.7
# 2                 503            1         33              0.9
# 3                 364            2         46              0.5
# 4                 364            2         46              0.7
# ...               ...          ...        ...              ...
# 3085              107            2        201              0.7
# 3086              107            2        201              0.9
# 3087              526            0        627              0.5
# 3088              526            0        627              0.7
# 3089              526            0        627              0.9
#
#       assessment_score
# 0                  0.5
# 1                  0.6
# 2                  0.7
# 3                  0.8
# 4                  0.9
# ...                ...
# 3085               0.9
# 3086               0.5
# 3087               0.6
# 3088               0.7
# 3089               0.8
#
# [3090 rows x 5 columns]

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
# Define models to test
models = {
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC(),
    'kNN': KNeighborsClassifier(),
    'Logistic Regression': LogisticRegression(),
    'Naive Bayes': GaussianNB()
}

# %%
# Dictionary to store results
results = {}

# Perform grid search for each model
for model_name, model in models.items():
    print(f"\nTesting {model_name}...")
    grid_search = GridSearchCV(estimator=model, param_grid={}, cv=3, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # Use the best model for predictions
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)

    # Evaluate the best model
    accuracy = accuracy_score(y_test, y_pred)
    results[model_name] = {
        'best_model': best_model,
        'accuracy': accuracy
    }
    print(f'Accuracy: {accuracy}')
    print(classification_report(y_test, y_pred))
# Out:
# Testing Decision Tree...
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(
# Accuracy: 0.8964401294498382
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         1
#            7       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         4
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         1
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00         3
#           18       1.00      1.00      1.00         6
#           20       1.00      1.00      1.00         1
#           22       1.00      1.00      1.00         2
#           23       1.00      1.00      1.00         1
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         1
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         3
#           29       1.00      1.00      1.00         4
#           30       1.00      1.00      1.00         1
#           31       1.00      1.00      1.00         2
#           32       1.00      1.00      1.00         1
#           33       1.00      1.00      1.00         2
#           34       1.00      1.00      1.00         2
#           35       1.00      1.00      1.00         1
#           36       1.00      1.00      1.00         1
#           37       1.00      1.00      1.00         2
#           38       0.33      0.50      0.40         2
#           39       1.00      1.00      1.00         1
#           40       1.00      1.00      1.00         1
#           41       1.00      1.00      1.00         1
#           42       1.00      1.00      1.00         2
#           43       0.50      1.00      0.67         1
#           44       1.00      0.40      0.57         5
#           45       1.00      1.00      1.00         1
#          326       0.00      0.00      0.00         1
#          327       0.00      0.00      0.00         1
#          328       0.00      0.00      0.00         2
#          329       0.00      0.00      0.00         1
#          330       0.00      0.00      0.00         2
#          331       0.22      1.00      0.36         4
#          333       0.00      0.00      0.00         1
#          335       0.00      0.00      0.00         3
#          336       0.00      0.00      0.00         2
#
#     accuracy                           0.03       618
#    macro avg       0.02      0.04      0.02       618
# weighted avg       0.01      0.03      0.02       618
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kyle\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Using the grid search, I found that the best model for the prediction is the decision tree model which comes with an accuracy of 89

# %%
# Now to show the results for the testing
print(results)
#Identify the model with the highest accuracy
best_model_name = max(results, key=lambda k: results[k]['accuracy'])
best_model = results[best_model_name]['best_model']
# Out:
# {'Decision Tree': {'best_model': DecisionTreeClassifier(), 'accuracy': 0.8964401294498382}, 'Random Forest': {'best_model': RandomForestClassifier(), 'accuracy': 0.10032362459546926}, 'SVM': {'best_model': SVC(), 'accuracy': 0.008090614886731391}, 'kNN': {'best_model': KNeighborsClassifier(), 'accuracy': 0.22653721682847897}, 'Logistic Regression': {'best_model': LogisticRegression(), 'accuracy': 0.01779935275080906}, 'Naive Bayes': {'best_model': GaussianNB(), 'accuracy': 0.032362459546925564}}

# %%
best_model
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Testing on manual data

# %%
# Manually input values for each feature
new_data_manual = pd.DataFrame({
    'skills_required': ['Python'],  
    'Skill_level': ['beginner'],  
    'interests': ['Analysis'], 
    'interest_Levels': [0.3],
    'assessment_score': [0.7]
})

# Label encoding for the manual data input
new_data_manual["skills_required"] = le_skills_required.transform(new_data_manual["skills_required"])
new_data_manual["Skill_level"] = le_skill_level.transform(new_data_manual["Skill_level"])
new_data_manual["interests"] = le_int.transform(new_data_manual["interests"])

# %%
X_manual = new_data_manual[['skills_required', 'Skill_level', 'interests', 'interest_Levels','assessment_score']]

# Making predictions using the best model
predictions_encoded_manual = best_model.predict(X_manual)

# Inverse transform the predicted labels to get the original labels
predictions_original_manual = le_career.inverse_transform(predictions_encoded_manual)

# Display the original labels
print(predictions_original_manual)
# Out:
# ['Data Scientist']

# %% [markdown]
# # Save the model to a file

# %%
joblib.dump(best_model, 'career_model.joblib')
# Out:
# ['career_model.joblib']

# %% [markdown]
# # Loading and using the model

# %%
# Load the saved model from the file
loaded_model = joblib.load('career_model.joblib')

# %%
# Manually input values for each feature
new_data_manual = pd.DataFrame({
    'skills_required': ['Python'],  
    'Skill_level': ['beginner'],  
    'interests': ['Analysis'], 
    'interest_Levels': [0.3],
    'assessment_score': [0.7]
})

# Label encoding for the manual data input
new_data_manual["skills_required"] = le_skills_required.transform(new_data_manual["skills_required"])
new_data_manual["Skill_level"] = le_skill_level.transform(new_data_manual["Skill_level"])
new_data_manual["interests"] = le_int.transform(new_data_manual["interests"])
X_manual = new_data_manual[['skills_required', 'Skill_level', 'interests', 'interest_Levels','assessment_score']]

# Making predictions using the career model
predictions_encoded_manual = loaded_model.predict(X_manual)

# Inverse transform the predicted labels to get the original labels
predictions_original_manual = le_career.inverse_transform(predictions_encoded_manual)

# Display the original labels
print(predictions_original_manual)
# Out:
# ['Data Scientist']

# %%
# %pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
