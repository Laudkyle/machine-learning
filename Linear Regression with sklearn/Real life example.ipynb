# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv('1.04. Real-life example.csv')
raw_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# ...

# %%
raw_data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# ...

# %% [markdown]
# ##  Droping a column

# %%
data = raw_data.drop(['Model'],1)

# %%
data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# unique           4            2          NaN
# ...

# %% [markdown]
# ##  Dealing with  missing values

# %%
data.isnull() # This is to check if that column has missing values
# Out:
#       Brand  Price   Body  Mileage  EngineV  Engine Type  Registration   Year
# 0     False  False  False    False    False        False         False  False
# 1     False  False  False    False    False        False         False  False
# 2     False  False  False    False    False        False         False  False
# 3     False  False  False    False    False        False         False  False
# 4     False  False  False    False    False        False         False  False
# ...     ...    ...    ...      ...      ...          ...           ...    ...
# 4340  False  False  False    False    False        False         False  False
# 4341  False  False  False    False    False        False         False  False
# 4342  False  False  False    False    False        False         False  False
# 4343  False  False  False    False     True        False         False  False
# 4344  False  False  False    False    False        False         False  False
#
# [4345 rows x 8 columns]

# %%
data.isnull().sum() # This brings out the number of entites
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %%
data_no_mv = data.dropna(axis=0) #This is to drop all the rows that have null values

# %%
data_no_mv
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
data_no_mv.describe(include ='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    4025.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   19552.308065    NaN   163.572174     2.764586
# std            NaN   25815.734988    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    90.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21900.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4025         4025  4025.000000
# unique           4            2          NaN
# ...

# %% [markdown]
# ## Ploting the Distribution one by one to check individual stats

# %%
sns.distplot(data_no_mv['Price'])
# Out:
# C:\Users\Kyle\anaconda2\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# #  Dealing with outliers

# %%
quantile = data_no_mv['Price'].quantile(0.96)
quantile
# Out:
# 70000.0

# %% [markdown]
# ##  Creating new data table for the data

# %%
data_1 = data_no_mv[data_no_mv['Price']<quantile]

# %%
data_1.describe()
# Out:
#               Price      Mileage      EngineV         Year
# count   3863.000000  3863.000000  3863.000000  3863.000000
# mean   15457.605736   169.874709     2.720062  2006.022262
# std    13258.011113   100.668539     5.028157     6.589701
# min      600.000000     0.000000     0.600000  1969.000000
# 25%     6899.500000   100.000000     1.800000  2002.000000
# 50%    10999.000000   161.000000     2.150000  2007.000000
# 75%    19900.000000   233.000000     3.000000  2011.000000
# max    69999.000000   980.000000    99.990000  2016.000000

# %%
quantile = data_1['Mileage'].quantile(0.95)
data_1 = data_1[data_1['Mileage']<quantile]

# %%
data_1 = data_1[data_1['EngineV']<6.5]

# %%
data_1.describe()
# Out:
#               Price      Mileage      EngineV         Year
# count   3643.000000  3643.000000  3643.000000  3643.000000
# mean   16004.845446   156.811419     2.407878  2006.551469
# std    13366.317865    84.284828     0.933130     6.230408
# min      600.000000     0.000000     0.600000  1969.000000
# 25%     7299.500000    95.500000     1.800000  2003.000000
# 50%    11500.000000   156.000000     2.000000  2008.000000
# 75%    20500.000000   220.000000     3.000000  2011.000000
# max    69999.000000   344.000000     6.300000  2016.000000

# %%
quantile = data_1['Year'].quantile(0.05)
data_2 = data_1[data_1['Year']>quantile]

# %%
data_2.describe()
# Out:
#               Price      Mileage      EngineV         Year
# count   3446.000000  3446.000000  3446.000000  3446.000000
# mean   16696.627063   153.685142     2.425830  2007.479977
# std    13386.584209    82.184686     0.946537     4.905023
# min      800.000000     0.000000     0.600000  1996.000000
# 25%     7900.000000    95.000000     1.800000  2004.000000
# 50%    12000.000000   153.000000     2.000000  2008.000000
# 75%    21300.000000   213.000000     3.000000  2012.000000
# max    69999.000000   344.000000     6.300000  2016.000000

# %%
sns.distplot(data_2['Year'])
# Out:
# C:\Users\Kyle\anaconda2\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %% [markdown]
# ##  Resting the index of the cleaned data

# %%
data_cleaned = data_2.reset_index(drop = True)

# %%
data_cleaned
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0           Audi  23000.0  crossover      240      4.2      Petrol
# 1         Toyota  18300.0  crossover      120      2.0      Petrol
# 2           Audi  14200.0      vagon      200      2.7      Diesel
# 3        Renault  10799.0      vagon      193      1.5      Diesel
# 4     Volkswagen   1400.0      other      212      1.8         Gas
# ...          ...      ...        ...      ...      ...         ...
# 3441     Renault   6800.0      sedan      152      1.6      Petrol
# 3442  Volkswagen  11500.0        van      163      2.5      Diesel
# 3443      Toyota  17900.0      sedan       35      1.6      Petrol
# 3444         BMW   6500.0      sedan        1      3.5      Petrol
# 3445  Volkswagen  13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  2007
# 1             yes  2011
# 2             yes  2006
# 3             yes  2012
# 4              no  1999
# ...

# %%
data_cleaned.describe(include ='all')
# Out:
#              Brand         Price   Body      Mileage      EngineV Engine Type  \
# count         3446   3446.000000   3446  3446.000000  3446.000000        3446
# unique           7           NaN      6          NaN          NaN           4
# top     Volkswagen           NaN  sedan          NaN          NaN      Diesel
# freq           773           NaN   1257          NaN          NaN        1615
# mean           NaN  16696.627063    NaN   153.685142     2.425830         NaN
# std            NaN  13386.584209    NaN    82.184686     0.946537         NaN
# min            NaN    800.000000    NaN     0.000000     0.600000         NaN
# 25%            NaN   7900.000000    NaN    95.000000     1.800000         NaN
# 50%            NaN  12000.000000    NaN   153.000000     2.000000         NaN
# 75%            NaN  21300.000000    NaN   213.000000     3.000000         NaN
# max            NaN  69999.000000    NaN   344.000000     6.300000         NaN
#
#        Registration         Year
# ...

# %% [markdown]
# #  Checking for OLS assumptions

# %% [markdown]
# ##  Drawing subplots

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3, sharey = True, figsize = (16,4))

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3, sharey = True, figsize = (16,4))
ax1.scatter(data_cleaned['Year'],data_cleaned['Price'])
ax1.set_title('Year and Price')
ax2.scatter(data_cleaned['EngineV'],data_cleaned['Price'])
ax2.set_title('EngineV and Price')
ax3.scatter(data_cleaned['Mileage'],data_cleaned['Price'])
ax3.set_title('Mileage and Price')
plt.show()

# %% [markdown]
# ####  Since the distributions are exponential instead of linear further action are going to be taken

# %% [markdown]
# ### Taking natural logs in order to transform the variables

# %%
log_price = np.log(data_cleaned['Price'])
data_cleaned['Price'] = log_price

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3, sharey = True, figsize = (16,4))
ax1.scatter(data_cleaned['Year'],data_cleaned['Price'])
ax1.set_title('Year and Log Price')
ax2.scatter(data_cleaned['EngineV'],data_cleaned['Price'])
ax2.set_title('EngineV and Log Price')
ax3.scatter(data_cleaned['Mileage'],data_cleaned['Price'])
ax3.set_title('Mileage and Log Price')
plt.show()

# %%
data_cleaned
# Out:
#            Brand      Price       Body  Mileage  EngineV Engine Type  \
# 0           Audi  10.043249  crossover      240      4.2      Petrol
# 1         Toyota   9.814656  crossover      120      2.0      Petrol
# 2           Audi   9.560997      vagon      200      2.7      Diesel
# 3        Renault   9.287209      vagon      193      1.5      Diesel
# 4     Volkswagen   7.244228      other      212      1.8         Gas
# ...          ...        ...        ...      ...      ...         ...
# 3441     Renault   8.824678      sedan      152      1.6      Petrol
# 3442  Volkswagen   9.350102        van      163      2.5      Diesel
# 3443      Toyota   9.792556      sedan       35      1.6      Petrol
# 3444         BMW   8.779557      sedan        1      3.5      Petrol
# 3445  Volkswagen   9.510445        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  2007
# 1             yes  2011
# 2             yes  2006
# 3             yes  2012
# ...

# %% [markdown]
# ##  Checking for multicolinearity

# %%
data_cleaned.columns.values
# Out:
# array(['Brand', 'Price', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year'], dtype=object)

# %% [markdown]
# ##  Sklearn does not have to dedicated method to check this hence we use statsmodels

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
variables =  data_cleaned[['Mileage', 'Year', 'EngineV']]
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(variables.values,i) for i in range(variables.shape[1])]
vif['Features'] = variables.columns

# %%
vif
# Out:
#          VIF Features
# 0   4.498040  Mileage
# 1  10.313344     Year
# 2   7.607847  EngineV

# %% [markdown]
# ###  vif should be between 1 and 5 so anything way above that is unacceptable hence we remove year

# %%
data_no_multicolinearity = data_cleaned.drop(['Year'],axis =1)

# %%
data_no_multicolinearity
# Out:
#            Brand      Price       Body  Mileage  EngineV Engine Type  \
# 0           Audi  10.043249  crossover      240      4.2      Petrol
# 1         Toyota   9.814656  crossover      120      2.0      Petrol
# 2           Audi   9.560997      vagon      200      2.7      Diesel
# 3        Renault   9.287209      vagon      193      1.5      Diesel
# 4     Volkswagen   7.244228      other      212      1.8         Gas
# ...          ...        ...        ...      ...      ...         ...
# 3441     Renault   8.824678      sedan      152      1.6      Petrol
# 3442  Volkswagen   9.350102        van      163      2.5      Diesel
# 3443      Toyota   9.792556      sedan       35      1.6      Petrol
# 3444         BMW   8.779557      sedan        1      3.5      Petrol
# 3445  Volkswagen   9.510445        van      124      2.0      Diesel
#
#      Registration
# 0             yes
# 1             yes
# 2             yes
# 3             yes
# 4              no
# ...           ...
# ...

# %% [markdown]
# #  Creating dummies for categorical data

# %%
data_dummies = pd.get_dummies(data_no_multicolinearity, drop_first =True)
data_dummies
# Out:
#           Price  Mileage  EngineV  Brand_BMW  Brand_Mercedes-Benz  \
# 0     10.043249      240      4.2          0                    0
# 1      9.814656      120      2.0          0                    0
# 2      9.560997      200      2.7          0                    0
# 3      9.287209      193      1.5          0                    0
# 4      7.244228      212      1.8          0                    0
# ...         ...      ...      ...        ...                  ...
# 3441   8.824678      152      1.6          0                    0
# 3442   9.350102      163      2.5          0                    0
# 3443   9.792556       35      1.6          0                    0
# 3444   8.779557        1      3.5          1                    0
# 3445   9.510445      124      2.0          0                    0
#
#       Brand_Mitsubishi  Brand_Renault  Brand_Toyota  Brand_Volkswagen  \
# 0                    0              0             0                 0
# ...

# %% [markdown]
# ##  Rearranging the columns

# %%
data_dummies.columns.values
# Out:
# array(['Price', 'Mileage', 'EngineV', 'Brand_BMW', 'Brand_Mercedes-Benz',
#        'Brand_Mitsubishi', 'Brand_Renault', 'Brand_Toyota',
#        'Brand_Volkswagen', 'Body_hatch', 'Body_other', 'Body_sedan',
#        'Body_vagon', 'Body_van', 'Engine Type_Gas', 'Engine Type_Other',
#        'Engine Type_Petrol', 'Registration_yes'], dtype=object)

# %%
cols = ['Price', 'Mileage', 'EngineV', 'Brand_BMW', 'Brand_Mercedes-Benz',
       'Brand_Mitsubishi', 'Brand_Renault', 'Brand_Toyota',
       'Brand_Volkswagen', 'Body_hatch', 'Body_other', 'Body_sedan',
       'Body_vagon', 'Body_van', 'Engine Type_Gas', 'Engine Type_Other',
       'Engine Type_Petrol', 'Registration_yes']

# %%
data_preprocessed = data_dummies[cols]

# %% [markdown]
# #  Creating the regression model itself

# %% [markdown]
# #  Defining inputs(x) and Target(y)

# %%
inputs =data_preprocessed.drop(['Price'],axis =1)
target = data_preprocessed['Price']

# %% [markdown]
# ##  Standardising

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
scaled_inputs = scaler.transform(inputs)

# %% [markdown]
# ##  Splitting the data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test, = train_test_split(inputs,target, test_size=0.2,  random_state=42)

# %% [markdown]
# #  The model

# %%
reg = LinearRegression()

reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([ 8.58489105,  8.12800369,  9.38820153, 10.69506433,  9.24010108,
#         8.79568577, 10.75574723,  9.60593949,  9.57105834,  9.33519551,
#         8.89040452,  9.73688887,  9.1557029 ,  8.81931888,  9.38126204,
#         8.58369901,  8.95356737,  8.43144079, 10.52699352,  9.29011805,
#         9.04244766,  9.57807284,  9.84111945,  8.60143405,  9.02675579,
#         8.94943429,  9.15003859,  7.94733088,  9.32962164,  8.3333994 ,
#         9.51716943,  9.80936977,  8.96608936, 10.1237092 ,  9.39783497,
#        10.85952389,  9.44513588,  9.57769498,  9.53636912,  9.66992616,
#         9.30005331,  8.60430193,  8.818519  ,  9.6153973 , 10.73355384,
#         8.18216892,  9.69308475,  9.59576473,  8.30116439,  9.30823911,
#         9.25908084,  9.35473348,  8.38938962,  9.05696091,  9.3988959 ,
#         9.70140629,  7.95752667,  9.91298953,  9.44263879,  8.80869689,
#         9.69493205,  8.78079452,  9.90739339, 10.14555302, 10.21628046,
# ...

# %%
y_hat = reg.predict(x_train)

plt.scatter(y_train, y_hat)
plt.xlabel('Training values')
plt.ylabel('Predicted values')
plt.xlim= 12
plt.ylim =12

# %% [markdown]
# ##  Residual plot

# %% [markdown]
# ###  Residual is the difference between the target and the predictions

# %%
sns.distplot(y_train - y_hat)
# Out:
# C:\Users\Kyle\anaconda2\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# ####  Since the mean is zero, we are good to go even though it has quite a long tail

# %%
reg.score(x_train,y_train)
# Out:
# 0.7498138555700362

# %%
reg.coef_
# Out:
# array([-0.00449285,  0.19430939,  0.07571972, -0.01542463, -0.55956449,
#        -0.59023413, -0.20151469, -0.21787349, -0.5501134 , -0.30416657,
#        -0.34714675, -0.38382018, -0.46538492, -0.2771879 , -0.18108423,
#        -0.25821572,  1.09412601])

# %%
reg.intercept_
# Out:
# 9.305552235019036

# %%
reg_summary = pd.DataFrame(data = inputs.columns.values, columns = ['Features'])
reg_summary['Weights'] = reg.coef_
reg_summary
# Out:
#                Features   Weights
# 0               Mileage -0.004493
# 1               EngineV  0.194309
# 2             Brand_BMW  0.075720
# 3   Brand_Mercedes-Benz -0.015425
# 4      Brand_Mitsubishi -0.559564
# 5         Brand_Renault -0.590234
# 6          Brand_Toyota -0.201515
# 7      Brand_Volkswagen -0.217873
# 8            Body_hatch -0.550113
# 9            Body_other -0.304167
# 10           Body_sedan -0.347147
# 11           Body_vagon -0.383820
# 12             Body_van -0.465385
# 13      Engine Type_Gas -0.277188
# 14    Engine Type_Other -0.181084
# 15   Engine Type_Petrol -0.258216
# 16     Registration_yes  1.094126

# %%
data_cleaned['Brand'].unique()
# Out:
# array(['Audi', 'Toyota', 'Renault', 'Volkswagen', 'BMW', 'Mitsubishi',
#        'Mercedes-Benz'], dtype=object)

# %% [markdown]
# ##  Testing

# %%
y_hat_test = reg.predict(x_test)

plt.scatter(y_test, y_hat_test ,alpha =0.3)
plt.xlabel('Testing values')
plt.ylabel('Predicted values')
plt.show()

# %%
df_pf = pd.DataFrame(data = y_hat_test , columns = ['Predictions'])
df_pf
# Out:
#      Predictions
# 0       8.584891
# 1       8.128004
# 2       9.388202
# 3      10.695064
# 4       9.240101
# ..           ...
# 685     8.916960
# 686     9.825679
# 687     7.911388
# 688     9.775758
# 689     9.093297
#
# [690 rows x 1 columns]

# %% [markdown]
# ##  Use np.exp to change from the log to normal values

# %%
df_pf = pd.DataFrame(data = np.exp(y_hat_test),columns = ["Predictions"] )
df_pf.head()
# Out:
#     Predictions
# 0   5350.209787
# 1   3388.029261
# 2  11946.594370
# 3  44137.468592
# 4  10302.079836

# %%
df_pf['Target'] = np.exp(target)

# %%
df_pf
# Out:
#       Predictions   Target
# 0     5350.209787  23000.0
# 1     3388.029261  18300.0
# 2    11946.594370  14200.0
# 3    44137.468592  10799.0
# 4    10302.079836   1400.0
# ..            ...      ...
# 685   7457.385554  58500.0
# 686  18502.833426  10200.0
# 687   2728.174865  13300.0
# 688  17601.827709   6300.0
# 689   8895.463891  16999.0
#
# [690 rows x 2 columns]

# %%
df_pf['Residual'] = df_pf['Target'] -df_pf['Predictions']
df_pf['Difference%'] =np.absolute(df_pf['Residual']/df_pf['Target']*100)
df_pf
# Out:
#       Predictions   Target      Residual  Difference%
# 0     5350.209787  23000.0  17649.790213    76.738218
# 1     3388.029261  18300.0  14911.970739    81.486179
# 2    11946.594370  14200.0   2253.405630    15.869054
# 3    44137.468592  10799.0 -33338.468592   308.718109
# 4    10302.079836   1400.0  -8902.079836   635.862845
# ..            ...      ...           ...          ...
# 685   7457.385554  58500.0  51042.614446    87.252332
# 686  18502.833426  10200.0  -8302.833426    81.400328
# 687   2728.174865  13300.0  10571.825135    79.487407
# 688  17601.827709   6300.0 -11301.827709   179.394091
# 689   8895.463891  16999.0   8103.536109    47.670664
#
# [690 rows x 4 columns]

# %%
df_pf.describe()
# Out:
#         Predictions        Target      Residual  Difference%
# count    690.000000    690.000000    690.000000   690.000000
# mean   15108.997671  16345.167464   1236.169793   110.309281
# std    10067.892630  13053.714475  16518.221203   176.841717
# min     1682.727889   1200.000000 -52165.008351     0.517552
# 25%     8478.612128   7992.250000  -7370.412284    30.592123
# 50%    12209.694576  11990.000000   -158.159235    60.561046
# 75%    18702.481181  19775.000000   8848.010665    93.341994
# max    59164.008351  69999.000000  63749.095371  1996.450745

# %%
df_pf.sort_values(by=['Difference%'])
# Out:
#       Predictions   Target      Residual  Difference%
# 325  29745.252064  29900.0    154.747936     0.517552
# 351  22652.112168  22800.0    147.887832     0.648631
# 638  13119.142817  13000.0   -119.142817     0.916483
# 630  17315.426685  17500.0    184.573315     1.054705
# 369  10379.851288  10250.0   -129.851288     1.266842
# ..            ...      ...           ...          ...
# 398  21681.720612   2000.0 -19681.720612   984.086031
# 266  43355.352278   3500.0 -39855.352278  1138.724351
# 462  34421.629766   2200.0 -32221.629766  1464.619535
# 268  33991.987532   1950.0 -32041.987532  1643.178848
# 165  29119.700854   1389.0 -27730.700854  1996.450745
#
# [690 rows x 4 columns]

# %% [markdown]
# ##  To see more rows, we use this

# %%
pd.options.display.max_rows =999
df_pf.sort_values(by=['Difference%'])
# Out:
#      Predictions   Target  Residual  Difference%
# 325     29745.25 29900.00    154.75         0.52
# 351     22652.11 22800.00    147.89         0.65
# 638     13119.14 13000.00   -119.14         0.92
# 630     17315.43 17500.00    184.57         1.05
# 369     10379.85 10250.00   -129.85         1.27
# 265      7703.76  7600.00   -103.76         1.37
# 53       8578.04  8700.00    121.96         1.40
# 169     23564.90 23900.00    335.10         1.40
# 449      6697.79  6799.00    101.21         1.49
# 631     24912.60 24500.00   -412.60         1.68
# 32       7832.91  7700.00   -132.91         1.73
# 253     17207.25 16900.00   -307.25         1.82
# 220      9433.41  9250.00   -183.41         1.98
# 410      9990.57 10200.00    209.43         2.05
# 465     17866.11 17500.00   -366.11         2.09
# 669     15141.26 15500.00    358.74         2.31
# 218     33981.46 34900.00    918.54         2.63
# 332     36140.24 35138.29  -1001.95         2.85
# ...

# %% [markdown]
# ##  Setting the decimal place

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x )

# %%
pd.options.display.max_rows =999
df_pf.sort_values(by=['Difference%'])
# Out:
#      Predictions   Target  Residual  Difference%
# 325     29745.25 29900.00    154.75         0.52
# 351     22652.11 22800.00    147.89         0.65
# 638     13119.14 13000.00   -119.14         0.92
# 630     17315.43 17500.00    184.57         1.05
# 369     10379.85 10250.00   -129.85         1.27
# 265      7703.76  7600.00   -103.76         1.37
# 53       8578.04  8700.00    121.96         1.40
# 169     23564.90 23900.00    335.10         1.40
# 449      6697.79  6799.00    101.21         1.49
# 631     24912.60 24500.00   -412.60         1.68
# 32       7832.91  7700.00   -132.91         1.73
# 253     17207.25 16900.00   -307.25         1.82
# 220      9433.41  9250.00   -183.41         1.98
# 410      9990.57 10200.00    209.43         2.05
# 465     17866.11 17500.00   -366.11         2.09
# 669     15141.26 15500.00    358.74         2.31
# 218     33981.46 34900.00    918.54         2.63
# 332     36140.24 35138.29  -1001.95         2.85
# ...
